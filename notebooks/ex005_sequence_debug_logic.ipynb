# %% [markdown]
# # Sequence Debug Logic
#
# ## Goal
# Complete each exercise cell, then run the tests.
#
# ## How to work
# - Write your solution(s) in the exercise cell(s)
# - Run `pytest -q`

# %% [markdown]
# # Exercise 1 — Expected behaviour
# The program should print a short greeting.
#
# ### Expected output
# ```
# Hi there!
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: wrong greeting value
    greeting = "Hello from Python!"
    return greeting

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 2 — Expected behaviour
# The program should say which subject the student enjoys.
#
# ### Expected output
# ```
# I enjoy coding lessons.
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: wrong subject value
    subject = "math"
    return "I enjoy " + subject + " lessons."

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 3 — Expected behaviour
# The program should state a favourite food.
#
# ### Expected output
# ```
# My favourite food is sushi
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: wrong food assigned
    food = "pasta"
    return "My favourite food is " + food

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 4 — Expected behaviour
# The program should prompt for a fruit and then show a short sentence.
#
# ### Expected output
# ```
# Type the name of your favourite fruit:
# I like mango
#
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: prompt text is different from expected
    prompt = "What is your favourite fruit?"
    fruit = "mango"

    return prompt + "\nI like " + fruit

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 5 — Expected behaviour
# The program should ask which town the user likes the most and say they'd visit the named town.
#
# ### Expected output
# ```
# Which town do you like the most?
# I would visit Cardiff
#
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: prompt text is incorrect
    prompt = "Tell me your favourite place:"
    place = "Cardiff"

    return prompt + "\nI would visit " + place

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 6 — Expected behaviour
# The program should prompt for a name and then welcome the person with punctuation.
#
# ### Expected output
# ```
# Please enter your name:
# Welcome, Alex!
#
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bugs: wrong prompt and greeting format
    prompt = "Enter your name:"
    name = "Alex"

    return prompt + "\nHello there, " + name

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 7 — Expected behaviour
# The program should combine two words into a short sentence.
#
# ### Expected output
# ```
# Variables matter
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: words are not the intended ones
    first_word = "Learning"
    second_word = "Python"

    return first_word + " " + second_word

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 8 — Expected behaviour
# The program should join two parts into `Keep experimenting`.
#
# ### Expected output
# ```
# Keep experimenting
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bug: second word is the wrong word
    part1 = "Keep"
    part2 = "coding"

    return part1 + " " + part2

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 9 — Expected behaviour
# The program should construct a friendly evening greeting for everyone.
#
# ### Expected output
# ```
# Good evening everyone!
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bugs: time_of_day and audience are incorrect
    greeting = "Good"
    time_of_day = "morning"

    audience = "students"
    return greeting + " " + time_of_day + " " + audience

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %% [markdown]
# # Exercise 10 — Expected behaviour
# The program should combine three parts into a single sentence.
#
# ### Expected output
# ```
# Variables and strings make a message!
# ```

# %%
# BUGGY IMPLEMENTATION (students edit this tagged cell)
def solve() -> object:
    # Logical bugs: wrong words and missing parts of the sentence
    part_one = "Python"
    part_two = "strings"

    part_three = "matter"
    return part_one + " " + part_two + " " + part_three

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %%
# Optional self-check (not graded)
# You can run small experiments here.
