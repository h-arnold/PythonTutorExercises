# %% [markdown]
# # Sequence Debug Logic
#
# ## Goal
# Complete each exercise cell, then run the tests.
#
# ## How to work
# - Write your solution(s) in the exercise cell(s)
# - Run `pytest -q`

# %% [markdown]
# # Exercise 1 — Expected behaviour
# The program should print a short greeting.
#
# ### Expected output
# ```
# Hi there!
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    greeting = "Hi there!"
    return greeting

# %% [markdown]
# ### What actually happened
# A wrong greeting text was used (`"Hello from Python!"`) which produced the incorrect output. The fix changes the variable to the expected message.

# %% [markdown]
# # Exercise 2 — Expected behaviour
# The program should say which subject the student enjoys.
#
# ### Expected output
# ```
# I enjoy coding lessons.
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    subject = "coding"
    return "I enjoy " + subject + " lessons."

# %% [markdown]
# ### What actually happened
# The code used `subject = "math"` so the sentence said the wrong subject. The fix uses `"coding"`.

# %% [markdown]
# # Exercise 3 — Expected behaviour
# The program should state a favourite food.
#
# ### Expected output
# ```
# My favourite food is sushi
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    food = "sushi"
    return "My favourite food is " + food

# %% [markdown]
# ### What actually happened
# The code assigned `food = "pasta"` which produced the wrong sentence. The fix assigns `"sushi"`.

# %% [markdown]
# # Exercise 4 — Expected behaviour
# The program should prompt for a fruit and then show a short sentence.
#
# ### Expected output
# ```
# Type the name of your favourite fruit:
# I like mango
#
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    prompt = "Type the name of your favourite fruit:"
    fruit = "mango"
    return prompt + "\nI like " + fruit

# %% [markdown]
# ### What actually happened
# The prompt text was incorrect (`"What is your favourite fruit?"`) so the output did not match the expected wording. The fix updates the prompt.

# %% [markdown]
# # Exercise 5 — Expected behaviour
# The program should ask which town the user likes the most and say they'd visit the named town.
#
# ### Expected output
# ```
# Which town do you like the most?
# I would visit Cardiff
#
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    prompt = "Which town do you like the most?"
    place = "Cardiff"
    return prompt + "\nI would visit " + place

# %% [markdown]
# ### What actually happened
# The prompt was `"Tell me your favourite place:"` which did not match the expected wording. The fix updates the prompt text.

# %% [markdown]
# # Exercise 6 — Expected behaviour
# The program should prompt for a name and then welcome the person with punctuation.
#
# ### Expected output
# ```
# Please enter your name:
# Welcome, Alex!
#
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    prompt = "Please enter your name:"
    name = "Alex"
    return prompt + "\nWelcome, " + name + "!"

# %% [markdown]
# ### What actually happened
# There were two issues: the prompt used `"Enter your name:"` and the greeting did not match the expected `"Welcome, Alex!"` format. Both were corrected.

# %% [markdown]
# # Exercise 7 — Expected behaviour
# The program should combine two words into a short sentence.
#
# ### Expected output
# ```
# Variables matter
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    first_word = "Variables"
    second_word = "matter"
    return first_word + " " + second_word

# %% [markdown]
# ### What actually happened
# The supplied words were `"Learning"` and `"Python"`. The fix sets the intended words `"Variables"` and `"matter"`.

# %% [markdown]
# # Exercise 8 — Expected behaviour
# The program should join two parts into `Keep experimenting`.
#
# ### Expected output
# ```
# Keep experimenting
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    part1 = "Keep"
    part2 = "experimenting"
    return part1 + " " + part2

# %% [markdown]
# ### What actually happened
# The second word was `"coding"` which produced a different sentence. The fix changes it to `"experimenting"`.

# %% [markdown]
# # Exercise 9 — Expected behaviour
# The program should construct a friendly evening greeting for everyone.
#
# ### Expected output
# ```
# Good evening everyone!
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    greeting = "Good"
    time_of_day = "evening"
    audience = "everyone!"

    return greeting + " " + time_of_day + " " + audience

# %% [markdown]
# ### What actually happened
# Both `time_of_day` and `audience` were incorrect (`"morning"`, "students"), producing the wrong message. Both were fixed.

# %% [markdown]
# # Exercise 10 — Expected behaviour
# The program should combine three parts into a single sentence.
#
# ### Expected output
# ```
# Variables and strings make a message!
# ```

# %%
# SOLUTION: corrected implementation
def solve() -> object:
    part_one = "Variables"
    part_two = "and strings"
    part_three = "make a message!"

    return part_one + " " + part_two + " " + part_three

# %% [markdown]
# ### What actually happened
# Several words were wrong (`"Python"`, `"strings"`, `"matter"`) and parts of the sentence were missing. The solution uses the intended words to form the full sentence.

# %%
# Optional self-check (not graded)
# You can run small experiments here.
